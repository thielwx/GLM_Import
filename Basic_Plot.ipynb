# %% [markdown]
# This code is designed to import and display the GLM data from GLM_DisplayTest

# %%
#import resources

import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import os
import cartopy.feature as cfeature
import cartopy.mpl as cmpl

# %%
#import netCDF file
nc_file = nc.Dataset('/Users/KevinThiel/Grad_School/GLM_DisplayTestData/GLM_HWT/IXTR98_NSSL_s20180728195000_e20180728195100_1MIN','r')

# %%
#makes the variable from the netCDF file into a local variable that we can use when plotting data
Average_flash_area = nc_file.variables['DQF'][::1]
x = nc_file.variables['x'][:]
y = nc_file.variables['y'][:]

# %%
print (np.shape(Average_flash_area))
# Out:
# (1499, 2499)

# %%
#creating plot with all the features
plt.figure(figsize=(14, 8))
ax = plt.axes(projection=ccrs.Geostationary(-75, 35786023.0))
#ax.set_extent([-87, -80, 25, 32])
ax.set_extent([-114, -61, 15, 52])
plt.contourf(x * 35786023.0, y * 35786023.0, Average_flash_area, cmap=plt.get_cmap('autumn_r'), zorder=10)
plt.title('GLM Average_flash_area 7-28-2018')
ax.coastlines(resolution='110m')
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.STATES, zorder=8, linestyle=':')
ax.add_feature(cfeature.BORDERS, zorder=9)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.RIVERS)

we = plt.colorbar()
#plt.savefig("Average_flash_area", orientation="landscape", format="ps")

# %%
Group_centroid_density = nc_file.variables['Group_centroid_density'][::1]
x = nc_file.variables['x'][:]
y = nc_file.variables['y'][:]

# %%
#creating plot with all the features
plt.figure(figsize=(14, 8))
ax = plt.axes(projection=ccrs.Geostationary(-75, 35786023.0))
#ax.set_extent([-88, -79, 20, 35])
plt.contourf(x * 35786023.0, y * 35786023.0, Group_centroid_density, cmap=plt.get_cmap('autumn_r'), zorder=10)
plt.title('GLM Group_cetroid_density 7-28-2018')
ax.coastlines(resolution='110m')
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.STATES, zorder=8, linestyle=':')
ax.add_feature(cfeature.BORDERS, zorder=9)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.RIVERS)

we = plt.colorbar()
#plt.savefig("Group_centroid_density", orientation="landscape", format="ps")

# %%
goes_imager_projection = nc_file.variables['x']

# %%
print (goes_imager_projection)
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int16 x(x)
#     long_name: GOES fixed grid projection x-coordinate
#     standard_name: projection_x_coordinate
#     axis: X
#     units: rad
#     add_offset: -0.101304
#     scale_factor: 5.6e-05
# unlimited dimensions:
# current shape = (2499,)
# filling on, default _FillValue of -32767 used

# %%
nc_file.variables['Flash_extent_density']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# uint8 Flash_extent_density(y, x)
#     _FillValue: 0
#     standard_name: Flash Extent Density
#     long_name: GLM Flash Extent Density
#     grid_mapping: goes_imager_projection
#     _Unsigned: true
# unlimited dimensions:
# current shape = (1499, 2499)
# filling on
